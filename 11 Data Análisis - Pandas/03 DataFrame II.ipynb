# %% [markdown]
# # DataFrame II
#
# Los objetivos de aprendizaje son:
#
# 1. Columnas
#     + ¿Qué es una columna?
#     + Seleccionar
#     + Modificar
#     + Crear
#     + .apply()
#     + Eliminar
# 2. Gestión Datos Nullos
#     + Drop
#     + Fill
# 3. Filtros
#     + Condiciones Lógicas
#     + .isin()
#     + .isnull()
#     + .between()
#     + .query()
#
#
# ## 1. Columnas
#
# ### ¿Qué es una columna?
#
# Desde una perspectiva de *data modeling*, una estructura tabular, tal y como lo es un DataFrame, nos ayuda a generar una representación abstracta de un objeto.

# %%
import numpy as np
import pandas as pd

nba_df = pd.read_csv("./Data/pandas/nba.csv")
nba_df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# Este modelo de datos serviría para representar a jugadores de la NBA, en este sentido:
#
# 1. Los renglones/filas representan jugadores.
# 2. **Las columnas representan caracteristicas de los jugadores**.
#
# Por ejemplo:
#
# El índice 2, representaría a un jugador cuya característica `Name = "John Holland"`.

# %% [markdown]
# ### Seleccionar
#
# Para seleccionar una columna de un `DataFrame` usaremos el comando
#
# ```python
# df[<nombre columna>]
# ````

# %%
nba_df['Name']
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
type(nba_df['Name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Una columna es en realidad un atributo de la clase DataFrame. Al ser una columna un atributo de la clase DataFrame, podemos acceder mediante la notación *dot*:
#
# ```Python
# dataframe.<nombre_columna>
# ```

# %%
nba_df.Team
# Out:
# 0      Boston Celtics
# 1      Boston Celtics
# 2      Boston Celtics
# 3      Boston Celtics
# 4      Boston Celtics
#             ...
# 453         Utah Jazz
# 454         Utah Jazz
# 455         Utah Jazz
# 456         Utah Jazz
# 457               NaN
# Name: Team, Length: 458, dtype: object

# %% [markdown]
# La primera opción es más flexibe para situaciones en las que los nombres de las columnas no cumplen con las reglas para nombrar variables en Python.
#
# Podemos seleccionar un grupo de columnas de la siguiente forma:

# %%
nba_df[["Name", "Team"]].head()
# Out:
#             Name            Team
# 0  Avery Bradley  Boston Celtics
# 1    Jae Crowder  Boston Celtics
# 2   John Holland  Boston Celtics
# 3    R.J. Hunter  Boston Celtics
# 4  Jonas Jerebko  Boston Celtics

# %%
columnas = [col for col in nba_df.columns if "a" in col.lower()]
print("Seleccionaremos las columns: {} \nResultado:".format(columnas))
nba_df[columnas].head()
# Out:
# Seleccionaremos las columns: ['Name', 'Team', 'Age', 'Salary']
# Resultado:
#             Name            Team   Age     Salary
# 0  Avery Bradley  Boston Celtics  25.0  7730337.0
# 1    Jae Crowder  Boston Celtics  25.0  6796117.0
# 2   John Holland  Boston Celtics  27.0        NaN
# 3    R.J. Hunter  Boston Celtics  22.0  1148640.0
# 4  Jonas Jerebko  Boston Celtics  29.0  5000000.0

# %% [markdown]
# ### Modificar
#
# En ocasiones, queremos alterar los valores de una columna aplicando alguna operación o función a cada elemento a.k.a. *element-wise operations* o *broadcasting*.

# %%
# Caso numérico 
nba_df[['Age']]
# Out:
#       Age
# 0    25.0
# 1    25.0
# 2    27.0
# 3    22.0
# 4    29.0
# ..    ...
# 453  26.0
# 454  24.0
# 455  26.0
# 456  26.0
# 457   NaN
#
# [458 rows x 1 columns]

# %%
nba_df[['Age']] + 1
# Out:
#       Age
# 0    26.0
# 1    26.0
# 2    28.0
# 3    23.0
# 4    30.0
# ..    ...
# 453  27.0
# 454  25.0
# 455  27.0
# 456  27.0
# 457   NaN
#
# [458 rows x 1 columns]

# %% [markdown]
# En el caso de las `strings` podemos aplicar métodos a cada registro del `DataFram`, pero tendremos que hacerlo con un cambio.
#
# Supongamos que queremos convertir a minúsculas la columna `Name`.

# %%
nba_df['Name'].head()
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %%
nba_df['Name'].lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/y9/xnm86z4j4p7fl2sqgd04cm1m0000gn/T/ipykernel_13453/3742138112.py in ?()
# ----> 1 nba_df['Name'].lower()
#
# ~/projects/curso-python-cac/.venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
nba_df['Name'].str.lower()
# Out:
# 0      avery bradley
# 1        jae crowder
# 2       john holland
# 3        r.j. hunter
# 4      jonas jerebko
#            ...
# 453     shelvin mack
# 454        raul neto
# 455     tibor pleiss
# 456      jeff withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %% [markdown]
# ### Crear
#
# Podemos añadir columnas a un DataFrame de una manera muy sencilla, veamos cómo hacerlo

# %%
nba_df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba_df["Columna_Extra"] = "Esto es una Columna Extra"
nba_df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary              Columna_Extra
# 0              Texas  7730337.0  Esto es una Columna Extra
# 1          Marquette  6796117.0  Esto es una Columna Extra
# 2  Boston University        NaN  Esto es una Columna Extra
# 3      Georgia State  1148640.0  Esto es una Columna Extra
# 4                NaN  5000000.0  Esto es una Columna Extra

# %% [markdown]
# Supongamos que queremos crear dos columnas a partir de la columna `Name`: `nombre` y `apellido`.

# %%
# Preimero separamos el campo Name
nba_df['Name'].str.split().head()
# Out:
# 0    [Avery, Bradley]
# 1      [Jae, Crowder]
# 2     [John, Holland]
# 3      [R.J., Hunter]
# 4    [Jonas, Jerebko]
# Name: Name, dtype: object

# %%
nba_df['nombre'] = nba_df['Name'].str.split().str[0]
nba_df['apellido'] = nba_df['Name'].str.split().str[1]
nba_df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary              Columna_Extra nombre apellido
# 0              Texas  7730337.0  Esto es una Columna Extra  Avery  Bradley
# 1          Marquette  6796117.0  Esto es una Columna Extra    Jae  Crowder
# 2  Boston University        NaN  Esto es una Columna Extra   John  Holland
# 3      Georgia State  1148640.0  Esto es una Columna Extra   R.J.   Hunter
# 4                NaN  5000000.0  Esto es una Columna Extra  Jonas  Jerebko

# %%
# También es posible realizar operaciones entre columnas.
nba_df['Age'] / nba_df['Weight']
# Out:
# 0      0.138889
# 1      0.106383
# 2      0.131707
# 3      0.118919
# 4      0.125541
#          ...
# 453    0.128079
# 454    0.134078
# 455    0.101562
# 456    0.112554
# 457         NaN
# Length: 458, dtype: float64

# %% [markdown]
# ### .apply()
#
# El método aplply nos permite aplicar funciones más complejas entre los valores de las columnas.
#
# Supongamos que queremos re-escalar el valor de la columna `Salary` en función del valor de la columna `Position`.
# Vamos los valores de la columna `Position`:

# %%
nba_df['Position'].value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %% [markdown]
# Ahora crearemos una función que:
#
# 1. Tendrá como input renglones de un DataFrae.
# 2. Extraerá los valores del DataFrame.
# 3. Realizará $n$ operaciones con ellos y regresará un valor.

# %%
def position_salary(row: pd.Series):
    position = row[0]
    salary = row[1]
    
    if position == "PG":
        return round(salary/2,2)
    elif position =="PF":
        return round(salary * 0.3,2)
    else:
        return salary

# %%
nba_df[['Position','Salary']].head()
# Out:
#   Position     Salary
# 0       PG  7730337.0
# 1       SF  6796117.0
# 2       SG        NaN
# 3       SG  1148640.0
# 4       PF  5000000.0

# %%
nba_df['Modified_Salary']= nba_df[['Position','Salary']].apply(position_salary, axis = 1)
nba_df[['Position','Salary','Modified_Salary']]
# Out:
#     Position     Salary  Modified_Salary
# 0         PG  7730337.0        3865168.5
# 1         SF  6796117.0        6796117.0
# 2         SG        NaN              NaN
# 3         SG  1148640.0        1148640.0
# 4         PF  5000000.0        1500000.0
# ..       ...        ...              ...
# 453       PG  2433333.0        1216666.5
# 454       PG   900000.0         450000.0
# 455        C  2900000.0        2900000.0
# 456        C   947276.0         947276.0
# 457      NaN        NaN              NaN
#
# [458 rows x 3 columns]

# %% [markdown]
# Pero... ¿Qué está pasando exactamente?

# %%
def test_by_row(row: pd.Series) -> None:
    print(row)
    print("\n")
    print("\tEl tipo de dato es : {}".format(type(row)))
    print("\tLos índices son: {}".format(row.index))
    print("\tEl valor con el índice 0 es: {}".format(row[0]))

# %%
_none = nba_df[['Name', 'Team']].head(1).apply(test_by_row, axis = 1)
# Out:
# Name     Avery Bradley
# Team    Boston Celtics
# Name: 0, dtype: object
#
#
# 	El tipo de dato es : <class 'pandas.core.series.Series'>
# 	Los índices son: Index(['Name', 'Team'], dtype='object')
# 	El valor con el índice 0 es: Avery Bradley

# %%
row_test = nba_df[['Name', 'Team']].head(1).transpose().squeeze()
row_test
# Out:
# Name     Avery Bradley
# Team    Boston Celtics
# Name: 0, dtype: object

# %% [markdown]
# Un momento, ¿Qué ha sucedido?
# * `transpose()` traspone el contenido del `DataFrame`, i.e. renglones -> columna
# * `squeeze()`, dado que el input es un objeto de la clase `DataFrame` con sólo una columna, transforma su input a un objeto de la clase `Series`

# %% [markdown]
# ### Eliminar Columnas
#
# El método [`.drop()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html) se usa para eliminar tanto renglones/filas como columnas. En esta sección veremos cómo usarlo en el caso de las columnas.

# %%
nba_df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary              Columna_Extra nombre apellido  \
# 0              Texas  7730337.0  Esto es una Columna Extra  Avery  Bradley
# 1          Marquette  6796117.0  Esto es una Columna Extra    Jae  Crowder
# 2  Boston University        NaN  Esto es una Columna Extra   John  Holland
# 3      Georgia State  1148640.0  Esto es una Columna Extra   R.J.   Hunter
# 4                NaN  5000000.0  Esto es una Columna Extra  Jonas  Jerebko
#
#    Modified_Salary
# 0        3865168.5
# 1        6796117.0
# 2              NaN
# 3        1148640.0
# 4        1500000.0

# %%
nba_df.drop(['nombre','apellido'], axis = 1, inplace = True)

# %%
nba_df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary              Columna_Extra  Modified_Salary
# 0              Texas  7730337.0  Esto es una Columna Extra        3865168.5
# 1          Marquette  6796117.0  Esto es una Columna Extra        6796117.0
# 2  Boston University        NaN  Esto es una Columna Extra              NaN
# 3      Georgia State  1148640.0  Esto es una Columna Extra        1148640.0
# 4                NaN  5000000.0  Esto es una Columna Extra        1500000.0

# %% [markdown]
# El parámetro `axis` nos permite elegir entre aplicar la acción anivel renglones `axis = 0` o columnas `axis = 1`.

# %%
nba_df.drop([0,2,4], axis = 0).head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#          College      Salary              Columna_Extra  Modified_Salary
# 1      Marquette   6796117.0  Esto es una Columna Extra        6796117.0
# 3  Georgia State   1148640.0  Esto es una Columna Extra        1148640.0
# 5            NaN  12000000.0  Esto es una Columna Extra        3600000.0
# 6            LSU   1170960.0  Esto es una Columna Extra         351288.0
# 7        Gonzaga   2165160.0  Esto es una Columna Extra        2165160.0

# %%
columnas = ['Team', 'Name', 'Number', 'Position', 'Age', 'Height', 'Weight',
       'College', 'Salary', 'Columna_Extra', 'Modified_Salary']
nba_df = nba_df[columnas]

# %%
nba_df.head()
# Out:
#              Team           Name  Number Position   Age Height  Weight  \
# 0  Boston Celtics  Avery Bradley     0.0       PG  25.0    6-2   180.0
# 1  Boston Celtics    Jae Crowder    99.0       SF  25.0    6-6   235.0
# 2  Boston Celtics   John Holland    30.0       SG  27.0    6-5   205.0
# 3  Boston Celtics    R.J. Hunter    28.0       SG  22.0    6-5   185.0
# 4  Boston Celtics  Jonas Jerebko     8.0       PF  29.0   6-10   231.0
#
#              College     Salary              Columna_Extra  Modified_Salary
# 0              Texas  7730337.0  Esto es una Columna Extra        3865168.5
# 1          Marquette  6796117.0  Esto es una Columna Extra        6796117.0
# 2  Boston University        NaN  Esto es una Columna Extra              NaN
# 3      Georgia State  1148640.0  Esto es una Columna Extra        1148640.0
# 4                NaN  5000000.0  Esto es una Columna Extra        1500000.0

# %% [markdown]
# ## 2. Gestión Datos Nullos
#
# En esta sección veremos cómo gestionar la ausencia de datos dentro de un DataFrame.
# Es muy probable que durante un proceso de análisis de datos lleguemos a encontrar valores faltantes, por ejemplo:
#
# En el DataFrame `nba_df` podemos ver que:
#
# 1. La entrada con índice 2 no tiene un valor para la columna `Salary`.
# 2. La entrada con índice 4 no tiene un valor para la columna `College`.

# %%
nba_df = pd.read_csv("./Data/pandas/nba.csv")
nba_df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# La ausencia de un valor dentro de Pandas se representa con el símbolo `NaN` (Not a Number).
#
# De manera general podemos elegir entre tres posibilidades:
#
# 1. Eliminarlos
# 2. Sustituirlos
# 3. Integrarlos en el proceso como un valor válido.

# %% [markdown]
# #### Eliminar - Registros o Columnas
#
# Para eliminar los registros podemos usar el método [`.dropna()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html)
#
# Los parámetros más importantes son:
#
# * `axis`: nos ayuda a elegir entre columnas o renglones
# * `how`: {`"any"`, `"all"`}: Determina si un renglón/columna será eliminado si tenemos al menos un NaN (`"any"`) o todos los valores como NaN (`"all"`)

# %%
nba_df.head().dropna(axis = 0, how = "any")
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#          College     Salary
# 0          Texas  7730337.0
# 1      Marquette  6796117.0
# 3  Georgia State  1148640.0

# %% [markdown]
# En este caso los registros con índice 2 y 4 fueron eliminados.

# %%
nba_df['ColumnaExtra_1'] = None
nba_df['ColumnaExtra_2'] = np.nan
nba_df['ColumnaExtra_3'] = pd.NA
nba_df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary ColumnaExtra_1  ColumnaExtra_2 ColumnaExtra_3
# 0              Texas  7730337.0           None             NaN           <NA>
# 1          Marquette  6796117.0           None             NaN           <NA>
# 2  Boston University        NaN           None             NaN           <NA>
# 3      Georgia State  1148640.0           None             NaN           <NA>
# 4                NaN  5000000.0           None             NaN           <NA>

# %%
nba_df.dropna(axis = 1, how = "all").head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba_df.dropna(axis = 1, how = "all", inplace = True)

# %% [markdown]
# #### Sustituir
#
# En lugar de eliminar la información podríamos asignar un valor a las entradas faltantes.
#
# ¿Qué valor asignar? La respuesta a esta pregunta dependerá mucho del tipo de datos y el objetivo del análisis, no obstante de manera general podemos aplicar las siguientes reglas:
#
# 1. Columna Numérica: Media.
# 2. Columna String: Moda, valor independiente.
#
# Usaremos el método [`.fillna()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html). De entre todos los poarámetros el más importante es `value`: El valor usado para sustituir el valor faltante/nulo.

# %%
nba_df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba_df[['Salary']].fillna(round(nba_df['Salary'].mean(),0)).head()
# Out:
#       Salary
# 0  7730337.0
# 1  6796117.0
# 2  4842684.0
# 3  1148640.0
# 4  5000000.0

# %% [markdown]
# Supongamos que queremos ejecutar esta acción sobre dos columnas en un sólo comando.

# %%
nba_df = nba_df.apply(
    lambda x: x.fillna(round(x.mean(),0)) if x.name in ["Salary", "Weight"] else x
)

# %%
nba_df['Salary'].isna().any()
# Out:
# False

# %% [markdown]
# En el caso de una columna del tipo `str`, una alternativa podría ser la moda.

# %%
from scipy import stats
nba_df.apply(
    lambda x: x.fillna(stats.mode(x).mode[0]) if x.dtype == "O" else x
).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/y9/xnm86z4j4p7fl2sqgd04cm1m0000gn/T/ipykernel_13453/1618015496.py in ?()
#       1 from scipy import stats
# ----> 2 nba_df.apply(
#       3     lambda x: x.fillna(stats.mode(x).mode[0]) if x.dtype == "O" else x
#       4 ).head()
#
# ~/projects/curso-python-cac/.venv/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, func, axis, raw, result_type, args, **kwargs)
#    9564             result_type=result_type,
#    9565             args=args,
#    9566             kwargs=kwargs,
#    9567         )
# -> 9568         return op.apply().__finalize__(self, method="apply")
#
# ~/projects/curso-python-cac/.venv/lib/python3.11/site-packages/pandas/core/apply.py in ?(self)
#     760         # raw
#     761         elif self.raw:
#     762             return self.apply_raw()
#     763
# --> 764         return self.apply_standard()
#
# ~/projects/curso-python-cac/.venv/lib/python3.11/site-packages/pandas/core/apply.py in ?(self)
#     890     def apply_standard(self):
# --> 891         results, res_index = self.apply_series_generator()
#     892
#     893         # wrap results
#     894         return self.wrap_results(results, res_index)
#
# ~/projects/curso-python-cac/.venv/lib/python3.11/site-packages/pandas/core/apply.py in ?(self)
#     903
#     904         with option_context("mode.chained_assignment", None):
#     905             for i, v in enumerate(series_gen):
#     906                 # ignore SettingWithCopy here in case the user mutates
# --> 907                 results[i] = self.f(v)
#     908                 if isinstance(results[i], ABCSeries):
#     909                     # If we have a view on v, we need to make a copy because
#     910                     #  series_generator will swap out the underlying data
#
# /var/folders/y9/xnm86z4j4p7fl2sqgd04cm1m0000gn/T/ipykernel_13453/1618015496.py in ?(x)
# ----> 3     lambda x: x.fillna(stats.mode(x).mode[0]) if x.dtype == "O" else x
#
# ~/projects/curso-python-cac/.venv/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py in ?(***failed resolving arguments***)
#     519                 # behavior of those would break backward compatibility.
#     520
#     521                 if sentinel:
#     522                     samples = _remove_sentinel(samples, paired, sentinel)
# --> 523                 res = hypotest_fun_out(*samples, **kwds)
#     524                 res = result_to_tuple(res)
#     525                 res = _add_reduced_axes(res, reduced_axes, keepdims)
#     526                 return tuple_to_result(*res)
#
# ~/projects/curso-python-cac/.venv/lib/python3.11/site-packages/scipy/stats/_stats_py.py in ?(a, axis, nan_policy, keepdims)
#     507         message = ("Argument `a` is not recognized as numeric. "
#     508                    "Support for input that cannot be coerced to a numeric "
#     509                    "array was deprecated in SciPy 1.9.0 and removed in SciPy "
#     510                    "1.11.0. Please consider `np.unique`.")
# --> 511         raise TypeError(message)
#     512
#     513     if a.size == 0:
#     514         NaN = _get_nan(a)
#
# TypeError: Argument `a` is not recognized as numeric. Support for input that cannot be coerced to a numeric array was deprecated in SciPy 1.9.0 and removed in SciPy 1.11.0. Please consider `np.unique`.

# %% [markdown]
# Pero esta elección dependerá mucho del contexto de los datos.
#
# Un dato faltante dentro de la columna `College`, en el contexto de los datos, podría significar que el jugador en cuestión no asistió a la universidad.
#
#
# Por tanto en este específico escenario, quizás nos interesará más estudiar el efecto de este nivel dentro de la variable `College`.

# %%
nba_df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN   222.0
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University  4842684.0
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457                NaN  4842684.0
#
# [458 rows x 9 columns]

# %%
nba_df = nba_df.apply(lambda x: x.fillna("No College") if x.name == "College" else x)

# %%
nba_df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN   222.0
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University  4842684.0
# 3        Georgia State  1148640.0
# 4           No College  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454         No College   900000.0
# 455         No College  2900000.0
# 456             Kansas   947276.0
# 457         No College  4842684.0
#
# [458 rows x 9 columns]

# %% [markdown]
# ## 3. Filtros
#
#
# ### Condiciones Lógicas
#
# Supongamos que del `DataFrame` `nba_df` sólo nos interesan aquellos jugadores con una edad $<= 25$.

# %%
nba_df['Age'] <= 25
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 453    False
# 454     True
# 455    False
# 456    False
# 457    False
# Name: Age, Length: 458, dtype: bool

# %% [markdown]
# Pero habíamos dicho que nos interesa mantener el resto de columnas.

# %%
nba_df[nba_df['Age'] <= 25]
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..              ...             ...     ...      ...   ...    ...     ...
# 446  Derrick Favors       Utah Jazz    15.0       PF  24.0   6-10   265.0
# 447     Rudy Gobert       Utah Jazz    27.0        C  23.0    7-1   245.0
# 449     Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 452      Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 454       Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
#
#            College      Salary
# 0            Texas   7730337.0
# 1        Marquette   6796117.0
# 3    Georgia State   1148640.0
# 6              LSU   1170960.0
# 7          Gonzaga   2165160.0
# ..             ...         ...
# 446   Georgia Tech  12000000.0
# 447     No College   1175880.0
# 449           Duke   1348440.0
# 452       Kentucky   2239800.0
# 454     No College    900000.0
#
# [199 rows x 9 columns]

# %% [markdown]
# ¿Qué pasaría si nos interesa que alguna otra condición también se cumpliera de manera simultánea? Por ejemplo, que `Age<=25` y que `Team=="Boston Celtics`

# %%
nba_df[
    (nba_df['Age']<=25) 
    & (nba_df['Team']=="Boston Celtics")
]
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8      Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 13      James Young  Boston Celtics    13.0       SG  20.0    6-6   215.0
#
#            College     Salary
# 0            Texas  7730337.0
# 1        Marquette  6796117.0
# 3    Georgia State  1148640.0
# 6              LSU  1170960.0
# 7          Gonzaga  2165160.0
# 8       Louisville  1824360.0
# 9   Oklahoma State  3431040.0
# 10      Ohio State  2569260.0
# 13        Kentucky  1749840.0

# %% [markdown]
# ¿Qué pasaría si nos interesaría que al menos alguna de las condiciones se cumpliera? Por ejemplo, que la primera letra de su nombre sea "A" o "B"

# %%
nba_df[
    (nba_df['Name'].str[0].str.lower()=="a") 
    | (nba_df['Name'].str[0].str.lower()=="b")
].head()
# Out:
#                 Name             Team  Number Position   Age Height  Weight  \
# 0      Avery Bradley   Boston Celtics     0.0       PG  25.0    6-2   180.0
# 5       Amir Johnson   Boston Celtics    90.0       PF  29.0    6-9   240.0
# 15  Bojan Bogdanovic    Brooklyn Nets    44.0       SG  27.0    6-8   216.0
# 23       Brook Lopez    Brooklyn Nets    11.0        C  28.0    7-0   275.0
# 30     Arron Afflalo  New York Knicks     4.0       SG  30.0    6-5   210.0
#
#        College      Salary
# 0        Texas   7730337.0
# 5   No College  12000000.0
# 15  No College   3425510.0
# 23    Stanford  19689000.0
# 30        UCLA   8000000.0

# %% [markdown]
# ### isin()
#
# El método [`.isin()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.isin.html) es una mejor alternativa.

# %%
nba_df[
    nba_df['Name'].str[0].str.lower().isin(['a','b'])
].head()
# Out:
#                 Name             Team  Number Position   Age Height  Weight  \
# 0      Avery Bradley   Boston Celtics     0.0       PG  25.0    6-2   180.0
# 5       Amir Johnson   Boston Celtics    90.0       PF  29.0    6-9   240.0
# 15  Bojan Bogdanovic    Brooklyn Nets    44.0       SG  27.0    6-8   216.0
# 23       Brook Lopez    Brooklyn Nets    11.0        C  28.0    7-0   275.0
# 30     Arron Afflalo  New York Knicks     4.0       SG  30.0    6-5   210.0
#
#        College      Salary
# 0        Texas   7730337.0
# 5   No College  12000000.0
# 15  No College   3425510.0
# 23    Stanford  19689000.0
# 30        UCLA   8000000.0

# %% [markdown]
# ### isnull()
#
# Vamos cómo filtrar datos nulos.

# %%
nba_df[nba_df['Age'].isnull()]
# Out:
#     Name Team  Number Position  Age Height  Weight     College     Salary
# 457  NaN  NaN     NaN      NaN  NaN    NaN   222.0  No College  4842684.0

# %% [markdown]
# Todos los registros con al menos un valor nulo en cualquiera de sus columnas.

# %%
nba_df = pd.read_csv("./Data/pandas/nba.csv")

# %%
nba_df.notnull().prod(axis = 1)<1
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 453    False
# 454     True
# 455     True
# 456    False
# 457     True
# Length: 458, dtype: bool

# %%
nba_df[nba_df.notnull().prod(axis = 1)<1]
# Out:
#                  Name            Team  Number Position   Age Height  Weight  \
# 2        John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4       Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5        Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 15   Bojan Bogdanovic   Brooklyn Nets    44.0       SG  27.0    6-8   216.0
# 20     Sergey Karasev   Brooklyn Nets    10.0       SG  22.0    6-7   208.0
# ..                ...             ...     ...      ...   ...    ...     ...
# 447       Rudy Gobert       Utah Jazz    27.0        C  23.0    7-1   245.0
# 450        Joe Ingles       Utah Jazz     2.0       SF  28.0    6-8   226.0
# 454         Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455      Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 457               NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College      Salary
# 2    Boston University         NaN
# 4                  NaN   5000000.0
# 5                  NaN  12000000.0
# 15                 NaN   3425510.0
# 20                 NaN   1599840.0
# ..                 ...         ...
# 447                NaN   1175880.0
# 450                NaN   2050000.0
# 454                NaN    900000.0
# 455                NaN   2900000.0
# 457                NaN         NaN
#
# [94 rows x 9 columns]

# %% [markdown]
# ¿Cómo contamos los valores nulos por columna?

# %%
pd.DataFrame(nba_df.isnull().sum(axis = 0).sort_values(ascending = False)).reset_index()
# Out:
#       index   0
# 0   College  85
# 1    Salary  12
# 2      Name   1
# 3      Team   1
# 4    Number   1
# 5  Position   1
# 6       Age   1
# 7    Height   1
# 8    Weight   1

# %% [markdown]
# ### between()
#
# Filtrar aquellos registros con un valor entre dos números[`.between()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.between.html).

# %%
nba_df[nba_df['Age'].between(25,27)]
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 11    Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# ..              ...             ...     ...      ...   ...    ...     ...
# 448  Gordon Hayward       Utah Jazz    20.0       SF  26.0    6-8   226.0
# 451   Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 453    Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 455    Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456     Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College      Salary
# 0                Texas   7730337.0
# 1            Marquette   6796117.0
# 2    Boston University         NaN
# 7              Gonzaga   2165160.0
# 11          Washington   6912869.0
# ..                 ...         ...
# 448             Butler  15409570.0
# 451             Dayton    981348.0
# 453             Butler   2433333.0
# 455                NaN   2900000.0
# 456             Kansas    947276.0
#
# [122 rows x 9 columns]

# %% [markdown]
# ### query()
#
# El método [`.query()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html) nos permite filtrar usando una condición codificada en formato `str`.
#
# Veamos cómo usarlo:

# %%
nba_df.query("Team == 'Boston Celtics'").head()

# %% [markdown]
# Pero el verdadero valor del método `.query()` viene por la opción de llegar a filtrar usando variables.

# %%
col = "Team"
value = 'Boston Celtics'

nba_df.query(f"{col} == '{value}'").head()
