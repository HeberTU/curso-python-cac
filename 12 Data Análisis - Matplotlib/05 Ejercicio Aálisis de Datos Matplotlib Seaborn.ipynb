# %% [markdown]
# # Ejercicio - Emblem look & feel
#
# El objetivo de este ejercicio será crear una función llamada `emblem_plot()` tal que:.
#
# 1. Que genere una gráfica en donde podamos visualizar de manera simultánea:
#
#     + Mediante un countplot el número de observaciones.
#     + Mediante un lineplot el valor agregado de una variable numérica usando cualquier tipo de función, e.g. mean, sd, etc.
#
# Importante, el barplot y lineplot no deberán ir en el mismo eje de las $y$, dado que la escala de valores podría estropear la visualización.
#
# 2. Tenga los siguiente parámetros:
#     * data: DataFrame a ocupar.
#     * x: Nombre de la columns con la variable categórico para agrupar los datos.
#     * y: Nombre de la columns con la variable numérica para agregar los datos.
#     * estimator: Función de agregación, e.g. media, desviación estándar.
#
# Para probar la funcionalidad utilizaremos a nuestro ya conocido DataFrame `tips`.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(10, 6)})

tips = sns.load_dataset('tips')

# %%
def emblem_plot(data, x, y, estimator):
    # Tu códico aquí
    pass

# %%
emblem_plot(data = tips, x = "smoker", y = "total_bill", estimator = np.mean)
